# %% [markdown]
# ## 1. Business Problem.
#
# An application that facilitates access to Monster Hunter 2 Dos data, the game is not very popular, due to that there are not many offline quick search tools about the game. The data that must contain in this application must be:
#
#     1.1. All Quests.
#     1.2. All Monster.
#     1.3. All Items.
#     1.4. All Kitchen Combinations.
#     1.5. Mix Sets.
#
# Ref:
#   - Wiki Jp: http://mh2kaiseki.web.fc2.com/
#   - Fandom: https://monsterhunter.fandom.com/wiki/Monster_Hunter_2

# %% [markdown]
# # 2. Objectives

# %% [markdown]
# ### 2.1. Final Product
#   - PySimpleGUI App.
#
# ### 2.2. Product Format
#   - mh2dos.exe
#
# ### 2.3. Local Download
#   - Mediafire.
#
# ### 2.4. Process
#   - Visual Design of App.
#   - Data Collect of Wiki and other Documents.
#   - Data Cleaning after Collection.
#   - Data Storange after Cleaning.
#   - Load data on App.
#   - Test and Log the App.
#   - Transform script on .exe
#   - Load on Mediafire Cloud.
#
# ### 2.5. Tools
#   - Python 3.8.0
#   - Jupyter Notebook for Data Collection.
#   - Gedit / Vim for Making Script.
#   - Pytrhon Libraries

# %%
from IPython.display import Image

Image( '../img/app_design.png' )
